# %% [markdown]
# # Clean Final Datastet

# %%
import numpy as np
import pandas as pd
import pyspark
import sys
import databricks.koalas as ks
import time

# %%
# Check spark app name
spark.sparkContext.appName
# Out:
# 'PySparkShell'

# %%
spark.conf.set("spark.sql.execution.arrow.pyspark.enabled", True)

# %%
# print runtime versions
# Python version
sys.version
# Out:
# '3.8.10 (default, Jun  2 2021, 10:49:15) \n[GCC 9.4.0]'

# %%
# Spark version
spark.version
# Out:
# '3.1.2'

# %%
pd.set_option("mode.use_inf_as_na", True)
ks.set_option('compute.ops_on_diff_frames', True)

# %% [markdown]
# ### Start

# %%
starttotal = time.time()

# %%
df = ks.read_csv('data/long_dataframe.csv')

# %%
names = list(df['name'].unique().sort_values().to_numpy())

# %%
names.remove('TWD/USD')
del names[-1]
names.append('TWD/USD')

# %%
# for name in names:
#     leng = df[df['name'] == name].shape[0]
#     print(f'{leng} is the lenght of {name}')

# %%
start = time.time()

# 先建立一個之後要對照的 Dataframe
df1 = df[df['name']=='1301.TW']

print(df1.shape, ' Original shape')

# 丟掉全是空值的 colown
allnanlist = list(df1.columns[np.where((df1.isnull().sum() == 2524).to_numpy())])
df1 = df1.drop(allnanlist, axis=1)

print(df1.shape, ' Later shape')

# 因 TAlib 計算式的關係，前面row會有空值(像是20日均線，前20天沒資料)，故在確認前 100 row 空值最大 row 數是多少
baseline = df1.iloc[:101,:].isnull().sum().max()
# 取 baseline 以後當新的 df # index reset
df1= df1.iloc[baseline:,:].reset_index(drop=True)

print(df1.shape, ' Final shape')

# 確認沒有 空值
print(df1.isnull().any().sum(),' Number of Nan')
# 確認沒有 無限值
print(df1.isna().any().sum(),' Number of Infinity')

# # 標準 columns
# standCols = df1.columns
# # 標準 Date
# standDate = df1['date']

end = time.time()
print(end - start)
# Out:
# (2524, 201)  Original shape
# (2524, 192)  Later shape
# (2436, 192)  Final shape
# 0  Number of Nan
# 0  Number of Infinity
# 45.541550636291504

# %%
# 丟掉全是空值的 colown, 也把 df 裡面的刪掉
df2 = df.drop(allnanlist, axis=1)

# %%
start = time.time()

for name in names[1:-2]:
    
    # 將一份股票讀入
    dft = df2[df2['name']== name]
       
    # 取 baseline 以後當新的 df # index reset    
    dft= dft.iloc[baseline:,:].reset_index(drop=True)
    
    
    if name == 'CrudeOil':
        dft = dft.fillna(method='ffill')
    
    # 判斷是否有 空值 與 無限值
    if dft.isnull().any().sum() != 0 or dft.isna().any().sum() != 0:
            
        print(f'{name} still has Nan or Infinity !!!')
        break
    
    # dataframe concat 合併
    else:
            
        df1 = ks.concat([df1, dft], ignore_index=True)
        print(f'{name} are in the clean long dataset !!!')
        
print('-'*100)
print('Finish !!!')

end = time.time()
print(end - start)
# Out:
# 1303.TW are in the clean long dataset !!!
# 1304.TW are in the clean long dataset !!!
# 1305.TW are in the clean long dataset !!!
# 1308.TW are in the clean long dataset !!!
# 1309.TW are in the clean long dataset !!!
# 1312.TW are in the clean long dataset !!!
# 1313.TW are in the clean long dataset !!!
# 1314.TW are in the clean long dataset !!!
# 1326.TW are in the clean long dataset !!!
# 2002.TW are in the clean long dataset !!!
# 2006.TW are in the clean long dataset !!!
# 2010.TW are in the clean long dataset !!!
# 2014.TW are in the clean long dataset !!!
# 2023.TW are in the clean long dataset !!!
# 2027.TW are in the clean long dataset !!!
# 2028.TW are in the clean long dataset !!!
# 2030.TW are in the clean long dataset !!!
# 2031.TW are in the clean long dataset !!!
# 2038.TW are in the clean long dataset !!!
# 2603.TW are in the clean long dataset !!!
# 2605.TW are in the clean long dataset !!!
# 2606.TW are in the clean long dataset !!!
# 2609.TW are in the clean long dataset !!!
# 2615.TW are in the clean long dataset !!!
# 2617.TW are in the clean long dataset !!!
# 2636.TW are in the clean long dataset !!!
# 2637.TW are in the clean long dataset !!!
# 5608.TW are in the clean long dataset !!!
# 5609.TWO are in the clean long dataset !!!
# BrentOil are in the clean long dataset !!!
# CrudeOil are in the clean long dataset !!!
# GC=F are in the clean long dataset !!!
# Iron are in the clean long dataset !!!
# ^DJI are in the clean long dataset !!!
# ^GSPC are in the clean long dataset !!!
# ^IXIC are in the clean long dataset !!!
# ^TWII are in the clean long dataset !!!
# ----------------------------------------------------------------------------------------------------
# Finish !!!
# 1373.6922388076782

# %%
# df1.shape -> (93027, 186)

# %%
# df1 = ks.read_parquet('data/tem.parquet')

# %%
# allnanlist[:2] #　['acos', 'asin']

# %%
# 把 df 裡面全是空值的 ['acos', 'asin']刪掉
df3 = df.drop(allnanlist[:2], axis=1)

# %%
start = time.time()

# 航運指數取出
shipdf = df3[df3['name'] == 'shippingIndex']

# 取 baseline row 以後的值
shipdf = shipdf.iloc[baseline:,:]

# dataframe concat 合併
df1 = ks.concat([df1, shipdf], ignore_index=True)

end = time.time()
print(end - start)
# Out:
# 52.85513162612915

# %%
start = time.time()

# 匯率取出
twddf = df3[df3['name'] == 'TWD/USD']

# 取 baseline row 以後的值
twddf = twddf.iloc[baseline:,:]

# dataframe concat 合併
df1 = ks.concat([df1, twddf], ignore_index=True)

end = time.time()
print(end - start)
# Out:
# 44.77653646469116

# %%
df1.to_spark().coalesce(1).write.option("header", "true").csv("name.csv")

# %%
# ndf = ks.read_csv('name.csv')

# %%
# ndf.shape
# Out:
# (96759, 199)

# %%
# ndf['category'].uniqueque()
# Out:
# 0       Steel
# 1     Futures
# 2     Plastic
# 3       Index
# 4    Shipping
# 5      ExRate
# Name: category, dtype: object

# %%
# ndf[ndf['category'] == 'Index'].isnull().sum()
# Out:
# date                       0
# category                   0
# name                       0
# open                    2436
# high                    2436
# low                     2436
# close                   2436
# volume                  2436
# year                    2436
# month                   2436
# day                     2436
# dayofyear               2436
# weekofyear              2436
# dayofweek               2436
# ht_dcperiod             2436
# ht_dcphase              2436
# inphase                 2436
# quadrature              2436
# sine                    2436
# leadsine                2436
# ht_trendmode            2436
# add                     2436
# div                     2436
# max23                   2436
# maxindex                2436
# min25                   2436
# minindex                2436
# min27                   2436
# max28                   2436
# minidx                  2436
# maxidx                  2436
# mult                    2436
# sub                     2436
# sum                     2436
# atan                    2436
# ceil                    2436
# cos                     2436
# cosh                    2436
# exp                     2436
# floor                   2436
# ln                      2436
# log10                   2436
# sin                     2436
# sinh                    2436
# sqrt                    2436
# tan                     2436
# tanh                    2436
# adx                     2436
# adxr                    2436
# apo                     2436
# aroondown               2436
# aroonup                 2436
# aroonosc                2436
# bop                     2436
# cci                     2436
# cmo                     2436
# dx                      2436
# macd59                  2436
# macdsignal60            2436
# macdhist61              2436
# macd62                  2436
# macdsignal63            2436
# macdhist64              2436
# macd65                  2436
# macdsignal66            2436
# macdhist67              2436
# mfi                     2436
# minus_di                2436
# minus_dm                2436
# mom                     2436
# plus_di                 2436
# plus_dm                 2436
# ppo                     2436
# roc                     2436
# rocp                    2436
# rocr                    2436
# rocr100                 2436
# rsi                     2436
# slowk                   2436
# slowd                   2436
# fastk82                 2436
# fastd83                 2436
# fastk84                 2436
# fastd85                 2436
# trix                    2436
# ultosc                  2436
# willr                   2436
# upperband               2436
# middleband              2436
# lowerband               2436
# dema                    2436
# ema                     2436
# ht_trendline            2436
# kama                    2436
# ma                      2436
# mama                    2436
# fama                    2436
# midpoint                2436
# midprice                2436
# sar                     2436
# sarext                  2436
# sma                     2436
# t3                      2436
# tema                    2436
# trima                   2436
# wma                     2436
# cdl2crows               2436
# cdl3blackcrows          2436
# cdl3inside              2436
# cdl3linestrike          2436
# cdl3outside             2436
# cdl3starsinsouth        2436
# cdl3whitesoldiers       2436
# cdlabandonedbaby        2436
# cdladvanceblock         2436
# cdlbelthold             2436
# cdlbreakaway            2436
# cdlclosingmarubozu      2436
# cdlconcealbabyswall     2436
# cdlcounterattack        2436
# cdldarkcloudcover       2436
# cdldoji                 2436
# cdldojistar             2436
# cdldragonflydoji        2436
# cdlengulfing            2436
# cdleveningdojistar      2436
# cdleveningstar          2436
# cdlgapsidesidewhite     2436
# cdlgravestonedoji       2436
# cdlhammer               2436
# cdlhangingman           2436
# cdlharami               2436
# cdlharamicross          2436
# cdlhighwave             2436
# cdlhikkake              2436
# cdlhikkakemod           2436
# cdlhomingpigeon         2436
# cdlidentical3crows      2436
# cdlinneck               2436
# cdlinvertedhammer       2436
# cdlkicking              2436
# cdlkickingbylength      2436
# cdlladderbottom         2436
# cdllongleggeddoji       2436
# cdllongline             2436
# cdlmarubozu             2436
# cdlmatchinglow          2436
# cdlmathold              2436
# cdlmorningdojistar      2436
# cdlmorningstar          2436
# cdlonneck               2436
# cdlpiercing             2436
# cdlrickshawman          2436
# cdlrisefall3methods     2436
# cdlseparatinglines      2436
# cdlshootingstar         2436
# cdlshortline            2436
# cdlspinningtop          2436
# cdlstalledpattern       2436
# cdlsticksandwich        2436
# cdltakuri               2436
# cdltasukigap            2436
# cdlthrusting            2436
# cdltristar              2436
# cdlunique3river         2436
# cdlupsidegap2crows      2436
# cdlxsidegap3methods     2436
# avgprice                2436
# medprice                2436
# typprice                2436
# wclprice                2436
# beta                    2436
# correl                  2436
# linearreg               2436
# linearreg_angle         2436
# linearreg_intercept     2436
# linearreg_slope         2436
# stddev                  2436
# tsf                     2436
# var                     2436
# atr                     2436
# natr                    2436
# trange                  2436
# ad                      2436
# adosc                   2436
# obv                     2436
# bias                    2436
# ama                     2436
# psy                     2436
# dpo                     2436
# vhf                     2436
# rvi                     2436
# BCI                     9744
# BCTI                    9744
# BDI                     9744
# BDTI                    9744
# BPI                     9744
# BSI                     9744
# NTD/USD                12180
# dtype: int64

# %%
endtotal = time.time()
print(starttotal-endtotal)

# %%
# Reference:

# 尋找缺失值位置
# np.where(np.isnan(dftt['trix'].to_numpy()))

# %%
# df2 = df[df['name']=='^TWII']

# %%
# # 保留前 100 row 空值小於等於 60% 的 column
# cond = df2.iloc[:101,:].isnull().sum()/100 <= 0.6
# df2 = df2[cond[cond == True].index.to_numpy()]

# %%
# # 因 TAlib 計算式的關係，前面row會有空值(像是20日均線，前20天沒資料)，故在確認前 100 row 空值最大 row 數是多少
# baseline = df2.iloc[:101,:].isnull().sum().max()

# %%
# # 取 baseline 以後當新的 df # index reset
# df2= df2.iloc[baseline:,:].reset_index(drop=True)

# %%
# np.where(df2.isnull().any().to_numpy() == True)
